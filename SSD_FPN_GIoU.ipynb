# %% [markdown]
# 先装载磁盘再进行后续操作

# %%
# !pwd
# Out:
# /content/drive/My Drive/SSD

# %% [markdown]
# 切换至磁盘不能用cd，要用以下方法

# %%
import os

# %%
os.chdir('drive/My Drive/SSD')

# %%
# !ls
# Out:
# pretrained-models.pytorch  SSD_FPN_GIoU.ipynb

# %% [markdown]
# 拉代码

# %%
# !git clone https://github.com/ChrisLiuxp/SSD_FPN_GIoU.git
# Out:
# Cloning into 'SSD_FPN_GIoU'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 68 (delta 8), reused 68 (delta 8), pack-reused 0
# Unpacking objects: 100% (68/68), done.

# %% [markdown]
# 下载数据集VOC2007，并解压

# %%
os.chdir('/content/drive/My Drive/SSD/SSD_FPN_GIoU/data')

# %%
# !wget http://pjreddie.com/media/files/VOCtrainval_06-Nov-2007.tar
# !wget http://pjreddie.com/media/files/VOCtest_06-Nov-2007.tar
# !wget http://pjreddie.com/media/files/VOCdevkit_08-Jun-2007.tar

# %%
# !tar xvf VOCtrainval_06-Nov-2007.tar
# !tar xvf VOCtest_06-Nov-2007.tar
# !tar xvf VOCdevkit_08-Jun-2007.tar

# %% [markdown]
# 装载pre_trained_model

# %%
# !pip install pretrainedmodels

# %%
# !git clone https://github.com/Cadene/pretrained-models.pytorch.git

# %%
os.chdir('pretrained-models.pytorch')

# %%
# !pwd
# Out:
# /content/drive/My Drive/SSD/pretrained-models.pytorch

# %%
# !python setup.py install

# %% [markdown]
# 装载完成，切换目录，就可以训练了

# %%
# !pwd
# Out:
# /content/drive/My Drive/SSD/SSD_FPN_GIoU/data

# %%
os.chdir('/content/drive/My Drive/SSD/SSD_FPN_GIoU')

# %%
# !pwd
# Out:
# /content/drive/My Drive/SSD/SSD_FPN_GIoU

# %% [markdown]
# 开始训练

# %%
# !pip install mmcv

# %%
# !pip install visdom

# %%
# !python tools/train.py
